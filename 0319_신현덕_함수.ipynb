# %% [markdown]
# # 함수 만들고 사용하기

# %%
# my_func()

# %%
# Out:
# 15

# %% [markdown]
# # 함수의 종류

# %%
# 내장함수: int()
# Out:
# 3

# %%
# 외장함수: sleep()

# %%
# 사용자정의 함수
# Out:
# 4

# %% [markdown]
# # 입력값과 결괏값에 따른 함수의 형태 4가지

# %%
# 일반적인 함수: adder()

# %%
# 결괏값만 있는 함수: return_something_long()

# %%
# 입력값만 함수: add_and_print()

# %%
# 입력값도 결괏값도 없는 함수: print_error()

# %% [markdown]
# # 매개변수 지정하여 호출하기

# %%
# add()

# %%
# Out:
# 2 3

# %% [markdown]
# # 입력값이 몇 개가 될지 모를 때는 어떻게 해야 할까?

# %%
# sum(*args)
